# %%
# Master Silver Orchestrator

notebooks = [
    "silver_layer_customer_table",
    "silver_layer_geolocation",
    "silver_layer_order_items",
    "silver_layer_order_payments_table",
    "silver_layer_order_reviews",
    "silver_layer_order_table",
    "silver_layer_product_category",
    "silver_layer_products_table",
    "silver_layer_sellers_table"
]

for nb in notebooks:
    print(f"Starting {nb}...")
    # The '0' is the timeout in seconds (0 means no timeout)
    dbutils.notebook.run(nb, 0)
    print(f"Finished {nb} successfully.")
